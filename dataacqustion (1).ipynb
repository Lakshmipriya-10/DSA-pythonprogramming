# %% [markdown]
# Load the dataset into a pandas DataFrame

# %%
import pandas as pd
data=pd.read_csv("/content/COVID-19_Outcomes_by_Vaccination_Status_-_Historical.csv")
data.head()
# Out:
#             Outcome    Week End Age Group  Unvaccinated Rate  Vaccinated Rate  \
# 0            Deaths  10/01/2022       All                0.3              0.1
# 1            Deaths  07/09/2022       0-4                0.0              NaN
# 2             Cases  11/12/2022       0-4               82.4              5.5
# 3  Hospitalizations  08/13/2022       0-4                7.4              0.0
# 4             Cases  02/26/2022       0-4               54.1              NaN
#
#    Boosted Rate  Crude Vaccinated Ratio  Crude Boosted Ratio  \
# 0           0.9                     3.0                  0.3
# 1           NaN                     NaN                  NaN
# 2           NaN                    15.0                  NaN
# 3           NaN                     NaN                  NaN
# 4           NaN                     NaN                  NaN
#
#    Age-Adjusted Unvaccinated Rate  Age-Adjusted Vaccinated Rate  ...  \
# ...

# %% [markdown]
# **Print the summary statistics of the dataset.**

# %%
data.describe()
# Out:
#        Unvaccinated Rate  Vaccinated Rate  Boosted Rate  \
# count        3753.000000      3426.000000   2529.000000
# mean           72.427498        42.439521     48.649783
# std           221.650961       148.091669    121.903690
# min             0.000000         0.000000      0.000000
# 25%             0.000000         0.000000      0.000000
# 50%             9.100000         2.500000      4.000000
# 75%            64.000000        29.975000     42.500000
# max          3690.900000      2009.500000   1520.300000
#
#        Crude Vaccinated Ratio  Crude Boosted Ratio  \
# count             2320.000000          1761.000000
# mean                 4.546940             2.952300
# std                  8.250405             4.668299
# min                  0.000000             0.000000
# 25%                  1.300000             1.000000
# 50%                  2.300000             1.600000
# 75%                  4.400000             3.200000
# ...

# %% [markdown]
# **What is the size of the dataset? (Number of rows and columns)**

# %%
data.shape
# Out:
# (3753, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3753 entries, 0 to 3752
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Outcome                         3753 non-null   object
#  1   Week End                        3753 non-null   object
#  2   Age Group                       3753 non-null   object
#  3   Unvaccinated Rate               3753 non-null   float64
#  4   Vaccinated Rate                 3426 non-null   float64
#  5   Boosted Rate                    2529 non-null   float64
#  6   Crude Vaccinated Ratio          2320 non-null   float64
#  7   Crude Boosted Ratio             1761 non-null   float64
#  8   Age-Adjusted Unvaccinated Rate  417 non-null    float64
#  9   Age-Adjusted Vaccinated Rate    417 non-null    float64
#  10  Age-Adjusted Boosted Rate       330 non-null    float64
#  11  Age-Adjusted Vaccinated Ratio   380 non-null    float64
# ...

# %% [markdown]
# **Q2: What are the data types of each column?**

# %%
data.dtypes
# Out:
# Outcome                            object
# Week End                           object
# Age Group                          object
# Unvaccinated Rate                 float64
# Vaccinated Rate                   float64
# Boosted Rate                      float64
# Crude Vaccinated Ratio            float64
# Crude Boosted Ratio               float64
# Age-Adjusted Unvaccinated Rate    float64
# Age-Adjusted Vaccinated Rate      float64
# Age-Adjusted Boosted Rate         float64
# Age-Adjusted Vaccinated Ratio     float64
# Age-Adjusted Boosted Ratio        float64
# Population Unvaccinated             int64
# Population Vaccinated             float64
# Population Boosted                float64
# Outcome Unvaccinated                int64
# Outcome Vaccinated                float64
# Outcome Boosted                   float64
# Age Group Min                       int64
# Age Group Max                       int64
# dtype: object

# %% [markdown]
# **Q3: Are there any missing values in the dataset? If so, which columns have
# missing values and how many?**

# %%
data.isnull().sum()
# Out:
# Outcome                              0
# Week End                             0
# Age Group                            0
# Unvaccinated Rate                    0
# Vaccinated Rate                    327
# Boosted Rate                      1224
# Crude Vaccinated Ratio            1433
# Crude Boosted Ratio               1992
# Age-Adjusted Unvaccinated Rate    3336
# Age-Adjusted Vaccinated Rate      3336
# Age-Adjusted Boosted Rate         3423
# Age-Adjusted Vaccinated Ratio     3373
# Age-Adjusted Boosted Ratio        3441
# Population Unvaccinated              0
# Population Vaccinated              540
# Population Boosted                1224
# Outcome Unvaccinated                 0
# Outcome Vaccinated                 327
# Outcome Boosted                   1224
# Age Group Min                        0
# Age Group Max                        0
# dtype: int64

# %% [markdown]
# **Q4: What are the unique values in a categorical column of your choice? How
# many unique values are there?**

# %%
data.nunique()
# Out:
# Outcome                              3
# Week End                           140
# Age Group                            9
# Unvaccinated Rate                 1287
# Vaccinated Rate                    915
# Boosted Rate                       834
# Crude Vaccinated Ratio             241
# Crude Boosted Ratio                163
# Age-Adjusted Unvaccinated Rate     272
# Age-Adjusted Vaccinated Rate       207
# Age-Adjusted Boosted Rate          176
# Age-Adjusted Vaccinated Ratio      109
# Age-Adjusted Boosted Ratio          86
# Population Unvaccinated           1088
# Population Vaccinated              963
# Population Boosted                 785
# Outcome Unvaccinated               513
# Outcome Vaccinated                 408
# Outcome Boosted                    430
# Age Group Min                        9
# Age Group Max                        9
# dtype: int64

# %%
data.columns
# Out:
# Index(['Outcome', 'Week End', 'Age Group', 'Unvaccinated Rate',
#        'Vaccinated Rate', 'Boosted Rate', 'Crude Vaccinated Ratio',
#        'Crude Boosted Ratio', 'Age-Adjusted Unvaccinated Rate',
#        'Age-Adjusted Vaccinated Rate', 'Age-Adjusted Boosted Rate',
#        'Age-Adjusted Vaccinated Ratio', 'Age-Adjusted Boosted Ratio',
#        'Population Unvaccinated', 'Population Vaccinated',
#        'Population Boosted', 'Outcome Unvaccinated', 'Outcome Vaccinated',
#        'Outcome Boosted', 'Age Group Min', 'Age Group Max'],
#       dtype='object')

# %% [markdown]
# **Q5: For a numerical column of your choice, calculate the mean, median, and
# standard deviation.**

# %%
mean_value = data['Population Vaccinated'].mean()
mean_value
# Out:
# 251186.79800809213

# %%
median_value=data['Population Vaccinated'].median()
median_value
# Out:
# 125723.0

# %%
standrd_deviation=data['Population Vaccinated'].std()
standrd_deviation
# Out:
# 309627.6610623851

# %% [markdown]
# **Q6: Identify any potential outliers in a numerical column of your choice. Explain
# your approach.**

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3753 entries, 0 to 3752
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Outcome                         3753 non-null   object
#  1   Week End                        3753 non-null   object
#  2   Age Group                       3753 non-null   object
#  3   Unvaccinated Rate               3753 non-null   float64
#  4   Vaccinated Rate                 3426 non-null   float64
#  5   Boosted Rate                    2529 non-null   float64
#  6   Crude Vaccinated Ratio          2320 non-null   float64
#  7   Crude Boosted Ratio             1761 non-null   float64
#  8   Age-Adjusted Unvaccinated Rate  417 non-null    float64
#  9   Age-Adjusted Vaccinated Rate    417 non-null    float64
#  10  Age-Adjusted Boosted Rate       330 non-null    float64
#  11  Age-Adjusted Vaccinated Ratio   380 non-null    float64
# ...

# %%
stats=data['Population Vaccinated'].describe()
stats
# Out:
# count    3.213000e+03
# mean     2.511868e+05
# std      3.096277e+05
# min      1.000000e+00
# 25%      7.363400e+04
# 50%      1.257230e+05
# 75%      2.784010e+05
# max      1.519169e+06
# Name: Population Vaccinated, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Population Vaccinated'])
plt.title('Box plot of population vaccinated')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['Population Vaccinated'], kde=True)
plt.title('Histogram of population vaccinated')
plt.xlabel('Population Vaccinated')
plt.show()

# %%
Q1 = data['Population Vaccinated'].quantile(0.25)
Q3 = data['Population Vaccinated'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

potential_outliers = data[(data['Population Vaccinated'] < lower_bound) | (data['Population Vaccinated'] > upper_bound)]
print(potential_outliers)
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 55    Hospitalizations  12/31/2022       All               17.1
# 59    Hospitalizations  05/06/2023       All                3.3
# 66               Cases  05/29/2021       All               63.9
# 70    Hospitalizations  12/04/2021       All               34.9
# ...                ...         ...       ...                ...
# 3702             Cases  01/15/2022       All             1213.5
# 3711            Deaths  02/12/2022       All                5.6
# 3724  Hospitalizations  09/04/2021       All               17.9
# 3733            Deaths  07/15/2023       All                0.2
# 3745  Hospitalizations  01/28/2023       All                8.7
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0                 0.1           0.9                     3.0
# 55                8.7          12.8                     2.0
# ...

# %% [markdown]
# **Q7: Find the correlation between numerical columns and discuss any interesting relationships.**

# %%
numerical_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numerical_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                 Unvaccinated Rate  Vaccinated Rate  \
# Unvaccinated Rate                        1.000000         0.920786
# Vaccinated Rate                          0.920786         1.000000
# Boosted Rate                             0.890207         0.906649
# Crude Vaccinated Ratio                  -0.057088        -0.120958
# Crude Boosted Ratio                      0.003474        -0.052728
# Age-Adjusted Unvaccinated Rate           0.999655         0.987640
# Age-Adjusted Vaccinated Rate             0.986072         0.998618
# Age-Adjusted Boosted Rate                0.933507         0.931370
# Age-Adjusted Vaccinated Ratio           -0.091495        -0.100684
# Age-Adjusted Boosted Ratio              -0.040481        -0.049354
# Population Unvaccinated                  0.001999        -0.018615
# Population Vaccinated                    0.015485        -0.017670
# Population Boosted                      -0.031845        -0.054987
# ...

# %% [markdown]
# **Q8: Group the data by a categorical column and compute the aggregate statistics
# (e.g., mean, sum) for a numerical column.**

# %%
data.groupby('Outcome')['Population Vaccinated'].agg(['mean', 'sum'])
# Out:
#                            mean          sum
# Outcome
# Cases             250906.881372  270728525.0
# Deaths            251470.941675  267313611.0
# Hospitalizations  251186.784314  269021046.0

# %% [markdown]
# **Q9:: Based on your analysis, provide a brief summary of any insights or patterns
# you discovered in the dataset.**

# %% [markdown]
# higher vaccination rates generally correlate with reduced COVID-19 cases and hospitalizations. However, correlations with mortality rates can vary and are influenced by multiple factors beyond vaccination alone. Understanding these relationships helps in evaluating the impact of vaccination campaigns and guiding public health policies to mitigate the impact of COVID-19. For precise insights, conducting the actual analysis on the specific dataset mentioned would provide more accurate and actionable findings.

# %% [markdown]
# **DATA VISUALIZATION**

# %%
pip install xlrd

# %%
plt.bar(data['Outcome'],data['Population Vaccinated'],color="red",width=0.2,edgecolor="black")
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
sns.histplot(data['Outcome'],bins=10)
plt.title("Histogram")
plt.xlabel('Population Vaccinated')
plt.show()
